# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('general_data.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data['NumCompaniesWorked']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       3.0
# 4       4.0
#        ...
# 4405    3.0
# 4406    2.0
# 4407    0.0
# 4408    0.0
# 4409    0.0
# Name: NumCompaniesWorked, Length: 4410, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,5))
sns.distplot(data['Age'],hist=False,color='orange',kde_kws = {"shade":True})

# %%
plt.figure(figsize=(5,5))
sns.distplot(data['DistanceFromHome'],hist=False,color='orange',kde_kws = {"shade":True})

# %%
plt.figure(figsize=(5,5))
sns.distplot(data['MonthlyIncome'],hist=False,color='orange',kde_kws = {"shade":True})

# %%
plt.figure(figsize=(5,5))
sns.distplot(data['NumCompaniesWorked'],hist=False,color='orange',kde_kws = {"shade":True})

# %%
data.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.006963  -0.035706            NaN
# DistanceFromHome         0.006963          1.000000  -0.008638            NaN
# Education               -0.035706         -0.008638   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008649         -0.001097  -0.009680            NaN
# JobLevel                -0.002884         -0.037329   0.045746            NaN
# MonthlyIncome           -0.044314         -0.021607   0.006410            NaN
# NumCompaniesWorked       0.299243         -0.013843  -0.016250            NaN
# PercentSalaryHike       -0.033137          0.038125  -0.040531            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031753          0.011169   0.001261            NaN
# ...

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
for i in data.columns:
    if(data[i].dtype=='object'):
        sns.countplot(x=i,hue='Attrition',data=data)
        plt.show()

# %%
sns.pairplot(data,hue='Attrition')
plt.show()
# Out:
# C:\Users\bodda\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\bodda\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\bodda\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\bodda\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
for i in data.columns:
    if(data[i].dtype!='object'):
        sns.boxplot(x=i,hue='Attrition',data=data)
        plt.show()

# %%
relationship_attrition = pd.crosstab(data['EducationField'], data['Attrition'], normalize = "index").reset_index()                                     # Find proportions across rows
print(relationship_attrition)
relationship_attrition.columns=['EducationField','b','c']
relationship_attrition['b']=relationship_attrition['b']*100
relationship_attrition['c']=relationship_attrition['c']*100
print(relationship_attrition)
sns.set_style('white')
plt.figure(figsize = (10,5))

# Plot the total percentage of employees first (i.e. 100%)
sns.barplot(x = 100, 
            y = "EducationField", 
            data = relationship_attrition, 
            
            color= "g")

# Plot the percentage of employees who churned 
sns.barplot(x = 'c', 
            y = "EducationField" , 
            data = relationship_attrition, 
            color= "r")
plt.show()
# Out:
# Attrition    EducationField        No       Yes
# 0           Human Resources  0.592593  0.407407
# 1             Life Sciences  0.833333  0.166667
# 2                 Marketing  0.842767  0.157233
# 3                   Medical  0.838362  0.161638
# 4                     Other  0.878049  0.121951
# 5          Technical Degree  0.886364  0.113636
#      EducationField          b          c
# 0   Human Resources  59.259259  40.740741
# 1     Life Sciences  83.333333  16.666667
# 2         Marketing  84.276730  15.723270
# 3           Medical  83.836207  16.163793
# 4             Other  87.804878  12.195122
# 5  Technical Degree  88.636364  11.363636

# %%
colwithoutliers=['MonthlyIncome','NumCompaniesWorked','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']
for i in colwithoutliers:
    print(i)
    IQR=data[i].quantile(0.75)-data[i].quantile(0.25)
    lower_bridge=data[i].quantile(0.25)-(IQR*1.5)
    higher_bridge=data[i].quantile(0.75)+(IQR*1.5)
    print(IQR,lower_bridge,higher_bridge)
for i in colwithoutliers:
    IQR=data[i].quantile(0.75)-data[i].quantile(0.25)
    lower_bridge=data[i].quantile(0.25)-(IQR*1.5)
    higher_bridge=data[i].quantile(0.75)+(IQR*1.5)
    data=data[data[i]<higher_bridge]
    print(data[i].max())
# Out:
# MonthlyIncome
# 39960.0 -31940.0 127900.0
# NumCompaniesWorked
# 3.0 -3.5 8.5
# TotalWorkingYears
# 6.0 -4.0 20.0
# TrainingTimesLastYear
# 1.0 0.5 4.5
# YearsAtCompany
# 4.0 -4.0 12.0
# YearsSinceLastPromotion
# 1.0 -1.5 2.5
# YearsWithCurrManager
# 3.0 -3.5 8.5
# 127420
# 8.0
# 19.0
# 4
# 11
# 2
# 7

# %%
colstoenco=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Attrition','Over18']
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
for i in colstoenco:
    data[i]=enc.fit_transform(data[i])
#data.head()colwithoutliers=['MonthlyIncome','NumCompaniesWorked','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
x=data.drop(['Attrition','NumCompaniesWorked'],axis=1)
y=data.Attrition
x.head()
# Out:
#     Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 1    31               1           1                10          1
# 4    32               2           1                10          1
# 6    28               2           1                11          2
# 7    29               2           1                18          3
# 14   28               2           1                 1          3
#
#     EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  ...  \
# 1                1              1           2       0         1  ...
# 4                3              1           5       1         1  ...
# 6                3              1           7       1         2  ...
# 7                1              1           8       1         2  ...
# 14               1              1          15       1         1  ...
#
#     MonthlyIncome  Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1566, 22) (392, 22) (1566,) (392,)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(max_depth=15,random_state=10)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9285714285714286

# %%
from sklearn.tree import export_graphviz
with open("Dtree.dot",'w') as f:
    f=export_graphviz(classifier,out_file=f)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\bodda'
